# %%
# !pip install pandas numpy scikit-learn
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/61.0 kB 1.4 MB/s eta 0:00:01
#      ---------------------------------------- 61.0/61.0 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ---------------------------------------- 60.6/60.6 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 4.1 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/11.5 MB 5.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.8/11.5 MB 6.5 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/11.5 MB 7.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.5 MB 7.1 MB/s eta 0:00:02
#    ------- -------------------------------- 2.3/11.5 MB 9.1 MB/s eta 0:00:02
# ...

# %%
import pandas as pd 
import numpy as np
